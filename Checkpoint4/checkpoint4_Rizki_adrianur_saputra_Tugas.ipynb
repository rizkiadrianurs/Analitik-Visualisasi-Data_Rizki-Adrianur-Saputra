# %% [markdown]
# ##**Judul: E-Commerce Parfum 2024**

# %% [markdown]
# Nama : Rizki Adrianur Saputra

# %% [markdown]
# Nim  : 2509116049

# %% [markdown]
# Kelas: B

# %% [markdown]
# ## **Import Library**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## Business Objective

# %% [markdown]
# Dataset yang digunakan pada penelitian ini merupakan data penjualan parfum pria yang berasal dari marketplace eBay. Dataset tersebut berisi berbagai informasi produk, seperti nama parfum, merek, harga, jumlah stok yang tersedia, jumlah produk yang telah terjual, serta lokasi penjual. Data ini menggambarkan aktivitas pelanggan dalam melakukan transaksi parfum pada platform e-commerce dan dapat digunakan untuk melihat bagaimana produk dipasarkan serta diminati oleh konsumen.
#
# Dalam dunia bisnis online, penjual sering menghadapi kesulitan dalam memahami faktor-faktor yang memengaruhi tingkat penjualan produk. Perbedaan harga antar produk, popularitas merek, serta ketersediaan stok dapat memberikan pengaruh yang berbeda terhadap keputusan pembelian konsumen. Tanpa analisis data yang tepat, penjual cenderung hanya mengandalkan perkiraan atau pengalaman pribadi dalam menentukan strategi penjualan. Oleh karena itu, analisis terhadap dataset ini dilakukan untuk memahami pola penjualan serta mengidentifikasi faktor-faktor yang berperan penting terhadap tinggi rendahnya penjualan parfum yang dijual pada platform e-commerce.

# %% [markdown]
# ## Assess Situation

# %% [markdown]
# Dataset yang digunakan pada penelitian ini memiliki 1000 baris data yang memilik beberapa informasi mengenai harga produk, jumlah stok yang tersedia, jumlah produk yang telah terjual, merek parfum,type parfume, waktu update serta lokasi penjual. Data ini sudah dapat digunakan sebagai bahan analisis awal. Namun, terdapat beberapa tantangan yang dihadapi oleh penjual, diantara lain:
# 1.   Beberapa kolom masih memiliki data yang kosong atau *missing values*
# 2.   format penulisan harga yang belum seragam
# 3. Variasi merek parfum yang beragam
# 4. Kemungkinan adanya outlier pada harga atau jumlah penjualan yang dapat mempengaruhi hasil analisis
#
# Oleh sebab itu, tahap persiapan data menjadi langkah penting agar dataset berada dapat lebih bersih dan siap digunakan, sehingga hasil analisis yang diperoleh nantinya dapat lebih akurat dan dapat dipercaya.

# %% [markdown]
# ## Analytic Goals

# %% [markdown]
# Dari dataset yang telah diamati, kita dapat menentukan tujuan berupa:
#
#
# 1. Memahami faktor-faktor yang dapat memengaruhi tingkat penjualan parfum pria di marketplace.
# 2.   Menganalisis hubungan antara harga produk, ketersediaan stok, serta merek parfum terhadap jumlah produk yang terjual.
# 3. Mengidentifikasi pola penjualan berdasarkan karakteristik produk yang tersedia pada dataset
# 4. Mengetahui kategori produk atau merek yang memiliki performa penjualan lebih baik dibandingkan produk lainnya.
# 5. Menganalisis pengaruh jenis parfum terhadap penjualan
# 6. Meneliti apakah lokasi penjual berpengaruh terhadap tingkat penjualan
#
# Melalui proses analisis ini, diharapkan dapat memperlihatkan pola penjualan yang muncul dari data, termasuk produk mana yang memiliki performa penjualan lebih baik dibandingkan yang lain. Diharapkan hasil analisis nantinya  dapat memberikan gambaran yang lebih jelas bagi penjual dalam menentukan strategi penetapan harga maupun pengelolaan produk, sehingga keputusan yang diambil tidak hanya berdasarkan perkiraan, tetapi juga didukung oleh data.

# %% [markdown]
# ## Project Plan

# %% [markdown]
# Rencana pengerjaan proyek analisis data ini akan dilakukan melalui beberapa tahapan berikut:
#
#
# 1.   Memahami struktur dan isi dataset
# 2.   Melakukan pembersihan data seperti menangani missing value dan memperbaiki format data
# 3. Menelaah data dan visualisasi untuk melihat pola dan distribusi data
# 4. Menganalisis hubungan antar variabel yang mempengaruhi penjualan
# 5. Menarik kesimpulan berdasarkan hasil analisis.
# 6. Mendokumentasikan hasil analisis secara sistematis

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %%
file= '/content/drive/MyDrive/Praktikum/ebay_mens_perfume (1).csv'

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              999 non-null    object
#  1   title              1000 non-null   object
#  2   type               997 non-null    object
#  3   price              1000 non-null   float64
#  4   priceWithCurrency  1000 non-null   object
#  5   available          889 non-null    float64
#  6   availableText      997 non-null    object
#  7   sold               994 non-null    float64
#  8   lastUpdated        947 non-null    object
#  9   itemLocation       1000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 78.3+ KB

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 1000 baris dan 10 kolom.

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              999 non-null    object
#  1   title              1000 non-null   object
#  2   type               997 non-null    object
#  3   price              1000 non-null   float64
#  4   priceWithCurrency  1000 non-null   object
#  5   available          889 non-null    float64
#  6   availableText      997 non-null    object
#  7   sold               994 non-null    float64
#  8   lastUpdated        947 non-null    object
#  9   itemLocation       1000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 78.3+ KB

# %% [markdown]
# 1. brand: Jumlah baris: 999 Tipe data: object Deskripsi: Merek produk parfum
#
# 2. title: Jumlah baris: 1000 Tipe data: object Deskripsi: Nama atau judul produk parfum
#
# 3. type: Jumlah baris: 997 Tipe data: object Deskripsi: Jenis atau kategori parfum
#
# 4. price: Jumlah baris: 1000 Tipe data: float64 Deskripsi: Harga produk parfum
#
# 5. priceWithCurrency: Jumlah baris: 1000 Tipe data: object Deskripsi: Harga produk beserta mata uang
#
# 6. available: Jumlah baris: 889 Tipe data: float64 Deskripsi: Status ketersediaan stok produk
#
# 7. availableText: Jumlah baris: 997 Tipe data: object Deskripsi: Informasi teks mengenai ketersediaan produk
#
# 8. sold: Jumlah baris: 994 Tipe data: float64 Deskripsi: Jumlah produk yang telah terjual
#
# 9. lastUpdated: Jumlah baris: 947 Tipe data: object Deskripsi: Waktu terakhir data diperbarui
#
# 10. itemLocation: Jumlah baris: 1000 Tipe data: object Deskripsi: Lokasi penjual atau asal produk

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: FutureWarning: Parsed string "May 24, 2024 10:26:59 PDT" included an un-recognized timezone "PDT". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                  brand                                              title  \
# count              999                                               1000
# unique             246                                                966
# top     Giorgio Armani  YSL Yves Saint Laurent Y Eau de Perfume Spray ...
# freq                60                                                  4
# mean               NaN                                                NaN
# std                NaN                                                NaN
# ...

# %% [markdown]
# **1.Count**
#
# berdasarkan data, total baris dataset adalah 1000 data. maka dapat disimpulkan:
#
# *   Brand hilang 1 data (1000 − 999)
# *   Type hilang 3 data (1000 − 997)
# *   Available hilang 111 data (1000 − 889)
# * Availabletext hilang 3 data (1000 − 997)
# * Sold hilang 6 data (1000 − 994)
# * lastupdated hilang 53 data (1000 − 947)
#
# kesimpulan: beberapa kolom masih mengandung missing values, terutama pada kolom available dan lastupdated, sedangkan kolom title, price, pricewithcurrency, dan itemlocation sudah lengkap (1000 data).
#
#
# ---
#
#
# **2.mean vs median**
# * Kolom Price
#   * Mean = 46.48
#   * Median = 35.71
#
#   nilai rata-rata lebih besar dari median, menunjukkan adanya beberapa parfum dengan harga sangat tinggi yang menarik rata-rata ke atas (outlier).
#
# * Kolom Available
#   * Mean = 20.05
#   * Median = 10.00
#
#   rata-rata jauh lebih besar dari median, menunjukkan sebagian kecil produk memiliki stok sangat banyak dibandingkan dengan mayoritas produk lainnya.
#
# * Kolom Sold
#   * Mean = 766.27
#   * Median = 49.50
#
#   rata-rata jauh lebih besar dari median, menunjukkan adanya produk dengan penjualan sangat tinggi sehingga distribusi data tidak merata.
#
# kesimpulan: secara keseluruhan distribusi data bersifat skewed right (condong ke kanan) terdapat beberapa nilai yang ekstrem sehingga memengaruhi nilai rata-rata pada seluruh variabel utama.
#
#
#
# ---
#
# **3.Min dan Max**
# * Price
#   * Min = 3.00
#   * Max = 259.090000
#
# * Available
#   * Min = 2
#   * Max = 842
#
# * Sold
#   * Min = 1
#   * Max = 54052.000000
#
# kesimpulan:nilai sold maksimum yang sangat besar yaitu 54.052 unit, perlu diperhatikan karena kemungkinan merupakan produk yang sangat populer atau adanya perbedaan jumlah penjualan antar produk. rentang harga parfum dari 3 hingga 259 masih tergolong wajar untuk pasar parfum online.
#
#
# ---
#
#
# **4.Standar Deviasi (std) - Variabilitas Data**
# * Price
#   * Mean = 46.481200
#   * Std = 35.527862
#
# * Sold
#   * Mean = 766.266600
#   * Std = 3200.971733
#
# Kesimpulan:pada kolom price, standar deviasi yang cukup besar menunjukkan variasi harga parfum cukup beragam dari murah hingga premium. pada kolom sold, nilai standar deviasi yang jauh lebih tinggi dari mean menandakan tingkat penjualan antar produk sangat tidak stabil, dengan sebagian kecil produk mendominasi penjualan.

# %% [markdown]
# ## **VERIFIKASI KUALITAS DATA**

# %% [markdown]
# ### **Data Type Check**

# %%
df.dtypes
# Out:
# brand                 object
# title                 object
# type                  object
# price                float64
# priceWithCurrency     object
# available            float64
# availableText         object
# sold                 float64
# lastUpdated           object
# itemLocation          object
# dtype: object

# %% [markdown]
# Dapat dilihat pada baris kolom di atas, banyak kolom yang memiliki tipe data object karena berisi teks seperti id, nama pelanggan, kategori, dan lokasi. kolom sales dan profit sudah sesuai karena menggunakan tipe data float64 untuk nilai numerik, serta kolom quantity menggunakan int64 untuk jumlah produk. Tetapi di kolom lastUpdate seharusnya menggunakan date agar bisa lebih sesui dengan tanggal, bulan, dan waktu.

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# #### **1. Brand**

# %%
print(df['brand'].unique())
# Out:
# ['Dior' 'AS SHOW' 'Unbranded' 'Giorgio Armani' 'Lattafa' 'Multiple Brands'
#  'Maison Alhambra' 'Gucci' 'Ralph Lauren' 'Dolce&Gabbana' 'SECERTMU'
#  'As Show' 'Versace' 'Paco Rabanne' 'Grandeur' 'Armaf' 'Carolina Herrera'
#  'Dolce & Gabbana' 'Clinique' 'Dumont' 'Afnan' 'Azzaro' "Penhaligon's"
#  'Bharara' 'Valentino' 'Guy Laroche' 'Montblanc' 'Rasasi' 'Calvin Klein'
#  'UOMO' 'Givenchy' 'Polo Ralph Lauren' 'C.K' 'John Varvatos' 'Nautica'
#  'As Picture Show' 'Kenneth Cole' 'Tommy Hilfiger' '2nd To None'
#  'Yves Saint Laurent' 'Cologne' 'AS SHOWN' 'Roja' 'MetaHerbal Labs'
#  'Mirage Brands' 'Abercrombie & Fitch' 'Moschino' 'As Shown'
#  '~ DOLCE & GABBANA ~' 'As picture show' 'Superz Budapest'
#  'Gianni Versace' 'Christian Dior' 'HERMÈS' 'Diesel' 'Lacoste' 'Dossier'
#  'Burberry' 'Michael Malul' 'Zara' 'Aramis' 'Jean Paul Gaultier'
#  'Davidoff' 'As Picture Shown' 'Bvlgari' 'Parfums de Marly'
#  'Salvatore Ferragamo' 'MontBlanc' 'Ard Al Zaafaran' 'Karl Lagerfeld'
# ...

# %% [markdown]
# Berdasarkan hasil pengecekan pada kolom brand, terlihat adanya inkonsistensi penulisan nama brand akibat perbedaan penggunaan huruf kapital, variasi penamaan, serta adanya kesalahan penulisan. contohnya seperti dolce & gabbana, mont blanc, dan yves saint laurent yang muncul dengan bentuk berbeda seperti huruf besar semua, huruf kecil, dan penambahan simbol tertentu. selain itu, terdapat juga beberapa nilai yang bukan merupakan nama brand, seperti as shown atau does not apply. perbedaan ini menyebabkan merek yang sama terbaca sebagai data yang berbeda dan masih terdapat data anomali, sehingga perlu dilakukan standarisasi penulisan dan perbaikan data agar data menjadi lebih rapi serta hasil analisis lebih akurat.

# %% [markdown]
# #### **2. Title**

# %%
print(df['title'].unique())
# Out:
# ["Christian Dior Sauvage Men's EDP 3.4 oz Fragrance Spray"
#  'A-v-entus Eau de Parfum 3.3 oz 100ML Millesime EDP Col-ogne for Men New In Box'
#  'HOGO BOSS cologne For Men 3.4 oz'
#  "Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau De Toilette Spray Men' New & Sealed"
#  "Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 oz Fragrances 6291108734056"
#  "Men's Perfume Sampler 10pcs Sample Vials Designer Fragrance Samples for Men"
#  'Glacier Bold by Maison Alhambra 3.4oz EDP for Men NEW SEALED CAN'
#  'Parfums De-Marly-Haltane Eau de Parfum spray 4.2 oz for Men New in Box'
#  'Hawas for him Eau De Parfum By Rasasi 100ml 3.4 FL OZ NEW'
#  'Gucci Guilty for Him - Classic 3oz Eau de Toilette Spray, Brand New'
#  'Polo Blue by Ralph Lauren 4.2 oz EDT Cologne for Men Brand New In Box'
#  'Dolce & Gabbana Light Blue Men 4.2 oz / 125 mL EDT Spray Brand New & Sealed'
#  'New 2024 Sexy Cologne Cupid Hypnosis Long Lasting Pheromone Perfume for Men'
# ...

# %% [markdown]
#  Berdasarkan hasil pengecekan pada kolom Title, terlihat adanya inkonsistensi penulisan nama brand akibat perbedaan penggunaan huruf kapital, variasi penamaan serta penulisan yang salah. Misalnya dior sauvage muncul sebagai sauvage eau de parfum, dior sauvage edp, sauvage for men, hingga penulisan yang salah seperti savage. selain itu terdapat juga perbedaan penggunaan huruf besar dan simbol pada nama produk. perbedaan ini menyebabkan title yang sama terbaca sebagai data yang berbeda, sehingga perlu dilakukan standarisasi penulisan dan perbaikan data agar data menjadi lebih rapi dan hasil analisis lebih akurat.

# %% [markdown]
# #### **3. Type**

# %%
print(df['type'].unique())
# Out:
# ['Eau de Parfum' 'Eau de Toilette' 'Fragrances' 'Perfume' '/' 'PARFUM'
#  'Parfum' 'Concentrated Uncut Pure Body Oil' 'LE PARFUM' 'Eau De Parfum'
#  nan 'Unscented' 'Eau de Cologne' '~ THE ONE EAU DE PARFUM SPRAY ~'
#  'EXTRAIT DE PARFUM' 'Eau De Toilette' 'Eau De Parfum Intense' 'Pheromone'
#  'Aftershave' 'Fragrance & Perfume' 'Eau de Perfume'
#  'Jo Malone Cologne Intense Spray' 'Y' 'Gift Sets'
#  'Fragrance Rolling Ball' 'Body Spray' 'Eau de toilette'
#  'Eau de Toillette'
#  'Eau De Toilette, Eau De Parfum, Eau De Parfum Intense' 'Cologne'
#  'le parfum' 'Eau de Toilette Intense'
#  'Eau de Cologne Spray, Cologne Spray' 'Extrait De Parfum' 'Fine Cologne'
#  'Does not apply' 'EDT' 'Extrait de Parfum' 'Editions Parfums'
#  'DIOR HOMME COLOGNE' 'Deodorant' 'De Nuit'
#  'Eau de Toilette, Cologne Spray' 'Parfum Intense' 'Eau de Parfum Intense'
#  'cologne' 'EAU DE COLOGNE SPRAY' 'Roll On' 'Elixir de Parfum' 'Elixir'
# ...

# %% [markdown]
# Berdasarkan hasil pengecekan pada kolom type, terlihat adanya inkonsistensi penulisan type produk akibat perbedaan penggunaan huruf kapital, variasi penamaan, serta kesalahan penulisan. misalnya eau de parfum ditulis dalam berbagai bentuk seperti Eau de Parfum, Eau De Parfum, EAU DE PARFUM, parfum, le parfum, hingga bentuk lain seperti EDP. hal serupa juga terjadi pada eau de toilette yang muncul sebagai Eau de Toilette, eau de toilette, EDT, dan Eau de Toillette. selain itu terdapat data yang bukan kategori konsentrasi parfum, seperti gift sets, deodorant, body spray, car air freshener, assorted, various, serta nilai umum seperti does not apply. perbedaan ini menyebabkan  type yang seharusnya sama terbaca sebagai data yang berbeda, sehingga perlu dilakukan standarisasi penulisan dan perbaikan data agar data menjadi lebih rapi serta hasil analisis lebih akurat.

# %% [markdown]
# #### **4. Price**

# %%
print(df['price'].unique())
# Out:
# [ 84.99 109.99 100.    44.99  16.91  14.99  30.99  85.    15.89  49.99
#   34.99  29.95  15.99  59.99  68.99  37.99  29.99  39.99  83.95  29.94
#   21.99  33.7   35.99  89.97  92.99  87.99 119.99  99.99  51.91  32.85
#   16.98  32.89  45.11  19.73  40.6   54.99  40.99  34.84  34.72  46.33
#   39.    21.54  32.97  23.34  28.75  27.94  32.5   45.95  69.99  13.99
#   36.88  24.7   26.11   6.65  25.99  60.99  47.88  31.08  24.43  38.57
#   24.45  16.26  22.5   15.03   8.32  37.8   23.56  27.59  26.5   35.71
#   23.89  10.99  70.99  16.99 126.99 159.99  39.95  13.66  89.99  92.56
#   13.86  17.99  79.99  33.95  24.5   49.96  26.97  30.   189.99 125.
#   28.91  25.43  11.   161.99  58.99  48.99  17.    65.97  36.68  20.
#   77.07  64.99  36.99  37.5   21.01   6.97  65.68  51.99  28.99  34.98
#   25.49  41.99  27.3   48.    45.68  82.99  11.99  32.99  17.85  38.24
#  125.99  36.36  33.45  44.    15.4   13.5   52.62  50.08  28.95  12.2
# ...

# %% [markdown]
# Berdasarkan hasil pengecekan pada kolom price, terlihat bahwa data sudah berbentuk numerik  dan memiliki banyak variasi nilai. harga produk berkisar mulai dari sekitar 3.00 hingga lebih dari 250.00, yang menunjukkan adanya perbedaan kelas produk, mulai dari parfum harga rendah hingga parfum premium. variasi harga yang besar ini merupakan kondisi yang wajar karena hal ini dipengaruhi oleh faktor merek, ukuran produk, konsentrasi parfum, serta edisi khusus. Tetapi, perlu dilakukan analisis lebih lanjut untuk memastikan tidak terdapat kesalahan input data serta agar hasil analisis harga menjadi lebih akurat.

# %% [markdown]
# #### **5. PriceWithCurrency**

# %%
print(df['price'].unique())
# Out:
# [ 84.99 109.99 100.    44.99  16.91  14.99  30.99  85.    15.89  49.99
#   34.99  29.95  15.99  59.99  68.99  37.99  29.99  39.99  83.95  29.94
#   21.99  33.7   35.99  89.97  92.99  87.99 119.99  99.99  51.91  32.85
#   16.98  32.89  45.11  19.73  40.6   54.99  40.99  34.84  34.72  46.33
#   39.    21.54  32.97  23.34  28.75  27.94  32.5   45.95  69.99  13.99
#   36.88  24.7   26.11   6.65  25.99  60.99  47.88  31.08  24.43  38.57
#   24.45  16.26  22.5   15.03   8.32  37.8   23.56  27.59  26.5   35.71
#   23.89  10.99  70.99  16.99 126.99 159.99  39.95  13.66  89.99  92.56
#   13.86  17.99  79.99  33.95  24.5   49.96  26.97  30.   189.99 125.
#   28.91  25.43  11.   161.99  58.99  48.99  17.    65.97  36.68  20.
#   77.07  64.99  36.99  37.5   21.01   6.97  65.68  51.99  28.99  34.98
#   25.49  41.99  27.3   48.    45.68  82.99  11.99  32.99  17.85  38.24
#  125.99  36.36  33.45  44.    15.4   13.5   52.62  50.08  28.95  12.2
# ...

# %% [markdown]
# Berdasarkan hasil pengecekan pada kolom PriceWithCurrency, terlihat bahwa sebagian besar harga parfum  sekitar 20–80, yang menunjukkan mayoritas produk dijual pada harga yang masih terjangkau oleh konsumen. Namun, terdapat beberapa harga yang jauh lebih tinggi dibandingkan harga lainnya, bahkan mencapai di atas 150 hingga lebih dari 200, sehingga mengindikasikan adanya produk kategori premium atau edisi khusus.berdasarkan hasil pengecekan pada kolom secara keseluruhan, variasi harga ini masih wajar, tetapi perlu dilakukan pemeriksaan kembali untuk memastikan tidak terjadi kesalahan input data.

# %% [markdown]
# #### **6. Available**

# %%
print(df['available'].unique())
# Out:
# [ 10.   8.   2.  nan   9.   7.   5.   4.   3. 620. 383.  71.  96. 756.
#  452. 161.  56.   6. 842. 484.  12. 322. 323.  33.  48. 116. 272. 226.
#  127. 224.  44. 124. 207. 310. 199. 101.  84.  31.  13. 487. 138.  66.
#   95. 155.  40.  52.  23.  36.  50.  72.  49.  24.  92.  82.  62. 202.
#  311.  16.  20. 129.  15.  22.  73.  51.  74.  60. 113.  93.  83. 102.
#  150.  47.  59.  53.  86.  26.  28.  39.  19.  57.  37.  54.  21.  65.
#   68. 110.  29. 130.  88.  45.]

# %% [markdown]
# Berdasarkan hasil pengecekan pada kolom Available, terlihat bahwa sebagian besar nilai berada pada rentang kecil hingga menengah sekitar 2–150, yang menunjukkan kebanyakan produk memiliki jumlah penjualan atau stok yang normal. namun, terdapat beberapa nilai yang sangat tinggi seperti di atas 300 hingga 800, yang mengindikasikan adanya produk dengan performa penjualan yang lebih besar dibandingkan yang lain atau kemungkinan perbedaan jenis data.

# %% [markdown]
# #### **7. AvailableText**

# %%
print(df['availableText'].unique())
# Out:
# ['More than 10 available / 116 sold' '8 available / 48 sold'
#  'More than 10 available / 27 sold' '2 available / 159 sold'
#  'Limited quantity available / 156 sold'
#  'More than 10 available / 79 sold' '9 available / 39 sold'
#  'Last One / 6 sold' '10 available / 17 sold' '8 available / 68 sold'
#  'More than 10 available / 615 sold' '7 available / 458 sold'
#  'More than 10 available / 889 sold' '9 available / 63 sold'
#  '7 available / 136 sold' '2 available / 20 sold'
#  'More than 10 available / 44 sold' '5 available / 384 sold'
#  'More than 10 available / 236 sold' '4 available / 22 sold'
#  'Limited quantity available / 9,208 sold' '4 available / 86 sold'
#  '3 available / 187 sold' 'More than 10 available / 131 sold'
#  '2 available / 43 sold' '10 available / 920 sold' '5 available / 19 sold'
#  '2 available / 4 sold' '10 available / 34 sold' 'Last One / 30 sold'
#  '4 available / 47 sold' '8 available / 170 sold'
# ...

# %% [markdown]
# Berdasarkan kolom availableText, terlihat bahwa sebagian besar nilai berada pada kisaran rendah hingga menengah, namun terdapat banyak nilai yang sangat besar hingga puluhan ribu. Hal ini menunjukkan adanya perbedaan jumlah data yang cukup jauh antar data. Tetapi sebaiknya dilakukan pemeriksaan kembali untuk memastikan bahwa semua nya telah sesuai sehingga nantinya dapat memudahkan dalam proses analisis.

# %% [markdown]
# #### **8. Sold**

# %%
print(df['sold'].unique())
# Out:
# [1.1600e+02 4.8000e+01 2.7000e+01 1.5900e+02 1.5600e+02 7.9000e+01
#  3.9000e+01 6.0000e+00 1.7000e+01 6.8000e+01 6.1500e+02 4.5800e+02
#  8.8900e+02 6.3000e+01 1.3600e+02 2.0000e+01 4.4000e+01 3.8400e+02
#  2.3600e+02 2.2000e+01 9.2080e+03 8.6000e+01 1.8700e+02 1.3100e+02
#  4.3000e+01 9.2000e+02 1.9000e+01 4.0000e+00 3.4000e+01 3.0000e+01
#  4.7000e+01 1.7000e+02 8.3850e+03 2.9500e+02 2.3450e+03 5.0320e+03
#  2.5800e+02 5.5000e+01 2.7600e+02 5.5820e+03 8.0000e+00 3.7000e+01
#  4.4600e+03 6.2700e+02 3.0655e+04 2.4000e+01 9.8900e+02 5.0230e+03
#  9.7200e+02 1.2739e+04 4.8500e+02 3.7200e+02 2.9100e+02 5.7800e+02
#  9.9000e+01 2.9000e+02 1.9899e+04 1.2865e+04 1.2184e+04 1.7200e+02
#  1.8882e+04 1.3320e+03 3.5000e+01 2.5000e+01 1.3620e+03 1.1000e+02
#  2.2100e+02 3.0000e+00 1.5030e+03 1.6910e+03 6.4400e+02 2.0000e+00
#  4.1700e+02 3.0000e+02 2.4048e+04 4.9720e+03 3.6000e+01 5.9400e+02
#  5.4052e+04 1.7900e+02 5.2000e+01 4.0400e+02 3.2000e+01 3.5300e+02
# ...

# %% [markdown]
# Berdasarkan kolom sold, terlihat bahwa sebaran nilai penjualan sangat bervariasi, dimana sebagian besar berada pada rentang puluhan hingga ratusan, namun terdapat beberapa nilai yang jauh lebih besar seperti 9.208, 30.655, 54.052, hingga 40.130. Sebaiknya dilakukan pemeriksaan kembali dan sebuah penanganan untuk memastikan bahwa semua nya telah sesuai sehingga nantinya dapat memudahkan dalam proses analisis.

# %% [markdown]
# #### **9. LastUpdated**

# %%
print(df['lastUpdated'].unique())
# Out:
# ['May 24, 2024 10:03:04 PDT' 'May 23, 2024 23:07:49 PDT'
#  'May 22, 2024 21:55:43 PDT' 'May 24, 2024 03:30:43 PDT'
#  'May 24, 2024 07:56:25 PDT' 'May 23, 2024 06:57:41 PDT'
#  'May 16, 2024 13:42:49 PDT' 'May 24, 2024 00:10:39 PDT'
#  'May 24, 2024 09:08:14 PDT' 'May 23, 2024 07:21:23 PDT'
#  'May 24, 2024 07:53:23 PDT' 'May 23, 2024 08:37:49 PDT'
#  'May 21, 2024 19:20:12 PDT' 'May 23, 2024 03:08:18 PDT'
#  'May 24, 2024 00:02:27 PDT' 'May 24, 2024 02:41:49 PDT'
#  'May 24, 2024 08:14:43 PDT' 'May 24, 2024 05:13:20 PDT'
#  'May 23, 2024 08:48:22 PDT' 'May 22, 2024 14:31:55 PDT'
#  'May 23, 2024 20:04:11 PDT' 'May 21, 2024 14:28:23 PDT'
#  'May 24, 2024 09:02:39 PDT' 'May 21, 2024 14:00:54 PDT'
#  'May 24, 2024 00:13:55 PDT' 'May 24, 2024 08:32:16 PDT'
#  'May 24, 2024 00:01:17 PDT' nan 'May 24, 2024 07:16:53 PDT'
#  'May 20, 2024 04:16:27 PDT' 'May 19, 2024 13:15:33 PDT'
#  'May 23, 2024 07:03:35 PDT' 'May 17, 2024 15:41:45 PDT'
# ...

# %% [markdown]
# Brdasarkan hasil pengecekan pada kolom lastupdated, format penulisan tanggal, bulan, dan tahun sudah terlihat baik serta konsisten karena seluruh data menggunakan format yang sama.

# %% [markdown]
# #### **10. Item Location**

# %%
print(df['itemLocation'].unique())
# Out:
# ['Allen Park, Michigan, United States' 'Atlanta, Georgia, Canada'
#  'Dearborn, Michigan, United States'
#  'Reinholds, Pennsylvania, United States'
#  'Brooklyn, New York, United States' 'Houston, Texas, United States'
#  'Englewood Cliffs, New Jersey, United States'
#  'Ithaca, New York, United States' 'shanghai, China'
#  'Dearborn Heights, Michigan, United States'
#  'Ecorse, Michigan, United States' 'Warren, Michigan, United States'
#  'San Francisco, California, United States' 'Dayton,New Jersey, Hong Kong'
#  'San Jose, California, United States' 'Miami, Florida, United States'
#  'Hamtramck, Michigan, United States' 'Flat Lick, Kentucky, United States'
#  'Elmhurst, New York, United States'
#  'Hackensack, New Jersey, United States' 'Dallas, Texas, United States'
#  'Pomona, California, United States' 'Katy, Texas, United States'
#  'College Point, New York, United States' 'NEW YORK, United States'
#  'New York,USA, Hong Kong' 'Brenham, Texas, United States'
# ...

# %% [markdown]
# Berdasarkan kolom location, terlihat adanya ketidakkonsistenan penulisan data lokasi, dimana format yang digunakan tidak sama, mulai dari penulisan lengkap hingga hanya negara atau kode wilayah saja. Selain itu, ada perbedaan penggunaan huruf kapital dan variasi penulisan nama lokasi yang sama seperti Hong Kong, HongKong, dan HK, serta beberapa data yang kurang jelas seperti adanya kode wilayah. Hal ini ini menyebabkan lokasi yang sebenarnya sama terbaca sebagai data yang berbeda, sehingga perlu dilakukan standarisasi penulisan agar data lebih rapi dan hasil analisis menjadi lebih akurat.

# %% [markdown]
# ### **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                    Null Ratio in %
# brand                          0.1
# title                          0.0
# type                           0.3
# price                          0.0
# priceWithCurrency              0.0
# available                     11.1
# availableText                  0.3
# sold                           0.6
# lastUpdated                    5.3
# itemLocation                   0.0

# %% [markdown]
# berdasarkan hasil pengecekan missing values, masih terdapat beberapa kolom yang memiliki nilai kosong atau null, yaitu brand sebesar 0,1%, type 0,3%, available 11,1%, availableText 0,3%, sold bold text 0,6%, dan lastUpdated 5,3%. kondisi ini menunjukkan bahwa masih ada informasi terkait brand, tipe produk, jumlah penjualan, ketersediaan produk, serta waktu pembaruan data yang belum terisi. hal tersebut perlu diperhatikan karena berpotensi memengaruhi analisis stok dan aktivitas penjualan, sehingga diperlukan penanganan seperti perbaikan atau pembersihan data agar hasil analisis menjadi lebih akurat. sementara itu, kolom lainnya tergolong aman karena memiliki persentase nilai kosong yang sangat kecil bahkan mencapai 0%, sehingga tingkat kelengkapan datanya sudah baik.

# %% [markdown]
# ### **Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [brand, title, type, price, priceWithCurrency, available, availableText, sold, lastUpdated, itemLocation]
# Index: []

# %% [markdown]
# Berdasarkan hasil pengecekan duplicated values, tidak ditemukan data yang terduplikasi pada dataset. hal ini menunjukkan bahwa setiap baris data sudah bersifat unik sehingga tidak terjadi pengulangan informasi, dan proses pembersihan data untuk duplikasi tidak perlu dilakukan.

# %% [markdown]
# ### **Outliers Values**

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom      Persentase Outliers
# price                      5.4
# available                 10.1
# sold                      13.6

# %% [markdown]
# Berdasarkan hasil deteksi outliers, terlihat bahwa ada kolom yang mmemiliki persentase nilai ekstrem. Yaitu kolom sold memiliki persentase nilai ekstrem sebesar 13,6%, kolom available sebesar 10,1% dan price sebesar 5,4%. Hal ini menunjukkan adanya perbedaan nilai yang cukup jauh pada sebagian data, terutama pada jumlah penjualan dan ketersediaan produk. kondisi tersebut dapat memengaruhi hasil analisis dan model yang akan kita bangun nantinya, sehingga perlu tindakan lebih lanjut.

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison**

# %%
penjualan_brand = df.groupby('brand')['sold'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=penjualan_brand.index,y=penjualan_brand.values,palette='viridis',hue=penjualan_brand.index,legend=False)

plt.title('10 Brand Teratas Berdasarkan Total Penjualan')
plt.xlabel('Brand Parfume')
plt.ylabel('Total Produk Terjual')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# berdasarkan visualisasi terhadap 10 brand teratas, terlihat bahwa brand Calvin Klein dan Versace menjadi brand dengan total penjualan tertinggi dibandingkan brand lainnya. sementara itu, brand seperti davidoff, azzaro, dan armaf berada pada tingkat penjualan menengah, sedangkan brand lain memiliki total penjualan yang lebih kecil. hal ini menunjukkan bahwa konsumen cenderung lebih menyukai brand populer yang sudah memiliki reputasi kuat di pasar parfum.

# %% [markdown]
# ## **Composition**

# %%
sales_by_brand = df.groupby('type')['sold'].sum().sort_values(ascending=False)

sales_by_brand_top3 = sales_by_brand.head(3)

plt.figure(figsize=(10, 8))
sales_by_brand_top3.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Paired.colors
)

plt.title('Proporsi 3 Type Teratas Berdasarkan Total Penjualan')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Berdasarkan diagram terhadap 3 type prafume terlaris, terlihat bahwa tipe eau de toilette mendominasi proporsi penjualan dengan persentase sekitar 86,8%, jauh lebih besar dibandingkan eau de parfum sebesar 8,4% dan eau de cologne sebesar 4,8%. hal ini menunjukkan bahwa konsumen lebih memilih eau de toilette, sehingga tipe ini menjadi type parfum yang paling banyak di beli oleh para konsumen.

# %% [markdown]
# ## **Distribution**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['sold'], bins=20, kde=True)

plt.title('Distribusi Jumlah Produk Terjual')
plt.xlabel('Jumlah Terjual (sold)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berdasarkan grafik distribusi tersebut, terlihat bahwa sebagian besar transaksi berada pada jumlah penjualan yang rendah, sedangkan hanya sedikit produk yang memiliki penjualan sangat tinggi. hal ini menunjukkan distribusi data condong ke kanan atau skewed right. Distribusi yang condong ke kanan ini menunjukkan adanya perbedaan penjualan yang cukup besar antar produk, yang berarti sebagian besar produk hanya terjual dalam jumlah sedikit, sementara hanya beberapa produk saja yang memiliki penjualan sangat tinggi dibandingkan yang lain.

# %% [markdown]
# ## **Relationship**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    df[['price', 'sold', 'available']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f')
plt.title('Korelasi Antar Variabel Numerik')
plt.show()

# %% [markdown]
# Berdasarkan heatmap korelasi, hubungan antara price dengan sold -0,08 dan available -0,10 yang berarti memiliki hubungan yang sangat lemah, sehingga harga produk tidak terlalu memengaruhi jumlah penjualan maupun ketersediaan stok. sementara itu, sold dan available memiliki korelasi positif rendah 0,26, yang menunjukkan bahwa produk dengan stok cenderung memiliki penjualan sedikit lebih tinggi, meskipun pengaruhnya tidak terlalu kuat. secara keseluruhan, tidak terdapat hubungan linear yang signifikan antar variabel pada dataset ini.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Data Type**

# %%
df["lastUpdated"] = pd.to_datetime(df["lastUpdated"], format="mixed")
# Out:
# /tmp/ipykernel_1398/1611178404.py:1: FutureWarning: Parsed string "May 24, 2024 10:03:04 PDT" included an un-recognized timezone "PDT". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["lastUpdated"] = pd.to_datetime(df["lastUpdated"], format="mixed")
# /tmp/ipykernel_1398/1611178404.py:1: FutureWarning: Parsed string "May 23, 2024 23:07:49 PDT" included an un-recognized timezone "PDT". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["lastUpdated"] = pd.to_datetime(df["lastUpdated"], format="mixed")
# ...

# %% [markdown]
# Tipe data lastUpdated perlu perlu dilakukan perubahan menjadi datetime karena jika masih berbentuk string object, data tanggal tidak bisa diproses atau dianalisis dengan benar. Dengan mengubahnya ke format tanggal, dapat melakukan perhitungan waktu, pengurutan, dan analisis berdasarkan kurun waktu secara lebih akurat dan efisien.

# %% [markdown]
# ## **Incosistent Values**

# %% [markdown]
# **1. Brand**

# %%
df['brand'] = df['brand'].str.title()
print(df['brand'].unique())
# Out:
# ['Dior' 'As Show' 'Unbranded' 'Giorgio Armani' 'Lattafa' 'Multiple Brands'
#  'Maison Alhambra' 'Gucci' 'Ralph Lauren' 'Dolce&Gabbana' 'Secertmu'
#  'Versace' 'Paco Rabanne' 'Grandeur' 'Armaf' 'Carolina Herrera'
#  'Dolce & Gabbana' 'Clinique' 'Dumont' 'Afnan' 'Azzaro' "Penhaligon'S"
#  'Bharara' 'Valentino' 'Guy Laroche' 'Montblanc' 'Rasasi' 'Calvin Klein'
#  'Uomo' 'Givenchy' 'Polo Ralph Lauren' 'C.K' 'John Varvatos' 'Nautica'
#  'As Picture Show' 'Kenneth Cole' 'Tommy Hilfiger' '2Nd To None'
#  'Yves Saint Laurent' 'Cologne' 'As Shown' 'Roja' 'Metaherbal Labs'
#  'Mirage Brands' 'Abercrombie & Fitch' 'Moschino' '~ Dolce & Gabbana ~'
#  'Superz Budapest' 'Gianni Versace' 'Christian Dior' 'Hermès' 'Diesel'
#  'Lacoste' 'Dossier' 'Burberry' 'Michael Malul' 'Zara' 'Aramis'
#  'Jean Paul Gaultier' 'Davidoff' 'As Picture Shown' 'Bvlgari'
#  'Parfums De Marly' 'Salvatore Ferragamo' 'Ard Al Zaafaran'
#  'Karl Lagerfeld' 'J. Del Pozo' 'Sean John' 'Ysl' 'Jaguar' 'Ebc'
# ...

# %%
df['brand'] = df['brand'].replace({
    'mont blanc': 'montblanc',
    'hermès': 'hermes',
    'ysl': 'yves saint laurent',
    'christian dior': 'dior',
    'giorgio arm.ani': 'giorgio armani'
})

for col in ['brand']:
    print(df[col].unique())
# Out:
# ['Dior' 'As Show' 'Unbranded' 'Giorgio Armani' 'Lattafa' 'Multiple Brands'
#  'Maison Alhambra' 'Gucci' 'Ralph Lauren' 'Dolce&Gabbana' 'Secertmu'
#  'Versace' 'Paco Rabanne' 'Grandeur' 'Armaf' 'Carolina Herrera'
#  'Dolce & Gabbana' 'Clinique' 'Dumont' 'Afnan' 'Azzaro' "Penhaligon'S"
#  'Bharara' 'Valentino' 'Guy Laroche' 'Montblanc' 'Rasasi' 'Calvin Klein'
#  'Uomo' 'Givenchy' 'Polo Ralph Lauren' 'C.K' 'John Varvatos' 'Nautica'
#  'As Picture Show' 'Kenneth Cole' 'Tommy Hilfiger' '2Nd To None'
#  'Yves Saint Laurent' 'Cologne' 'As Shown' 'Roja' 'Metaherbal Labs'
#  'Mirage Brands' 'Abercrombie & Fitch' 'Moschino' '~ Dolce & Gabbana ~'
#  'Superz Budapest' 'Gianni Versace' 'Christian Dior' 'Hermès' 'Diesel'
#  'Lacoste' 'Dossier' 'Burberry' 'Michael Malul' 'Zara' 'Aramis'
#  'Jean Paul Gaultier' 'Davidoff' 'As Picture Shown' 'Bvlgari'
#  'Parfums De Marly' 'Salvatore Ferragamo' 'Ard Al Zaafaran'
#  'Karl Lagerfeld' 'J. Del Pozo' 'Sean John' 'Ysl' 'Jaguar' 'Ebc'
# ...

# %% [markdown]
# **2. Title**

# %%
df['title'] = df['title'].str.title()
print(df['title'].unique())
# Out:
# ["Christian Dior Sauvage Men'S Edp 3.4 Oz Fragrance Spray"
#  'A-V-Entus Eau De Parfum 3.3 Oz 100Ml Millesime Edp Col-Ogne For Men New In Box'
#  'Hogo Boss Cologne For Men 3.4 Oz'
#  "Acqua Di Gio By Giorgio Armani 6.7 Fl Oz Eau De Toilette Spray Men' New & Sealed"
#  "Lattafa Men'S Hayaati Al Maleky Edp Spray 3.4 Oz Fragrances 6291108734056"
#  "Men'S Perfume Sampler 10Pcs Sample Vials Designer Fragrance Samples For Men"
#  'Glacier Bold By Maison Alhambra 3.4Oz Edp For Men New Sealed Can'
#  'Parfums De-Marly-Haltane Eau De Parfum Spray 4.2 Oz For Men New In Box'
#  'Hawas For Him Eau De Parfum By Rasasi 100Ml 3.4 Fl Oz New'
#  'Gucci Guilty For Him - Classic 3Oz Eau De Toilette Spray, Brand New'
#  'Polo Blue By Ralph Lauren 4.2 Oz Edt Cologne For Men Brand New In Box'
#  'Dolce & Gabbana Light Blue Men 4.2 Oz / 125 Ml Edt Spray Brand New & Sealed'
#  'New 2024 Sexy Cologne Cupid Hypnosis Long Lasting Pheromone Perfume For Men'
# ...

# %%
df["title"] = df["title"].replace({
    "savage": "sauvage",
    "dior sauvage edp": "dior sauvage",
    "sauvage for men": "dior sauvage",
    "Khadlaj Karus Blu Spice 3.4 Edp New 🆕": "Khadlaj Karus Blu Spice 3.4 Edp",
    "ItS Essential Edp Perfume By Rasasi 100 Ml🥇Hot New Rasasi Premium Line🥇": "ItS Essential Edp Perfume By Rasasi 100 Ml",
    "New 2024 Sexy Cologne Lure Her Him Long Lasting Pheromone Perfume For Men Usa✅": "New 2024 Sexy Cologne Lure Her Him Long Lasting Pheromone Perfume For Men Usa",
    "~The One Eau De Parfum Spray~": "The One Eau De Parfum Spray",
    "9 Am Dive Edp Perfume By Afnan 100 Ml🥇Super Famous Top Selling Fragrance 9Pm": "9 Am Dive Edp Perfume By Afnan 100 Ml",
    "Lacoste Essential Eau De Toilette Pour Homme ~ 4.2 Fl Oz ~ Sealed ~ Authentic": "Lacoste Essential Eau De Toilette Pour Homme",
    "Armaf Club De Nuit Sillage 1.0 Oz / 30Ml Eau De Parfum Spray | Unisex | Sealed |":"'Armaf Club De Nuit Sillage 1.0 Oz / 30Ml Eau De Parfum Spray, Unisex, Sealed",
    "Lacoste Essential Eau De Toilette Pour Homme ~ 4.2 Fl Oz ~ Sealed ~ Authentic": "Lacoste Essential Eau De Toilette Pour Homme",
    "Armaf Club De Nuit Intense 5.07Oz / 150Ml Pure Parfum | Brand New | Sealed":"Armaf Club De Nuit Intense 5.07Oz / 150Ml Pure Parfum Brand New Sealed",
    "Abercrombie & Fitch Fierce 1.7 Oz Eau De Cologne Men - New - Free Ship-Authentic": "Abercrombie & Fitch Fierce 1.7 Oz Eau De Cologne Men New Free Ship Authentic",
    "Odyssey Mandarin Sky Limited Edition Edp Perfume By Armaf 100Ml🥇Top Fragrance🥇": "Odyssey Mandarin Sky Limited Edition Edp Perfume By Armaf 100Ml Top Fragrance",
    "Hollister Jake Cologne Eau De Cologne 1.7 Oz/50 Ml Ne🦋 Sealed Men": "Hollister Jake Cologne Eau De Cologne 1.7 Oz/50 Ml Ne Sealed Men",
    "Boss Bottled Infinite By Hugo Boss Edp For Men 3.3 Oz / 100 Ml *New*": "Boss Bottled Infinite By Hugo Boss Edp For Men 3.3 Oz / 100 Ml New",
    "L'Eau D'Issey By Issey Miyake Pour Homme Eau De Toilette ~ 2.5 Fl Oz ~ Sealed": "L'Eau D'Issey By Issey Miyake Pour Homme Eau De Toilette",
    "Socal By Hollister So Cal 1.7 Oz 50Ml Eau De Cologne Spray Men New 🌺Sealed": "Socal By Hollister So Cal 1.7 Oz 50Ml Eau De Cologne Spray Men New Sealed",
    "Sealed New Cupid Hypnosis Men’S Pheromone Cologne 1.7 Oz | Meet More Hot Women": "Sealed New Cupid Hypnosis Men’S Pheromone Cologne 1.7 Oz Meet More Hot Women",
    "Brilliant Silver Edp Perfume By Rasasi 100 Ml:🥇Hot New Rasasi Premium Line🥇": "Brilliant Silver Edp Perfume By Rasasi 100 Ml:Hot New Rasasi Premium Line",
    "Mahogany Teakwood Cologne 3.4Oz Spray Collection Bath And & Body Works Ne🦋 2024": "Mahogany Teakwood Cologne 3.4Oz Spray Collection Bath And Body Works Ne 2024",
    "Boss Bottled Infinite By Hugo Boss Edp For Men 3.3 Oz / 100 Ml": "Boss Bottled Infinite By Hugo Boss Edp For Men 3.3 Oz / 100 Ml",
    "It'S Essential Edp Perfume By Rasasi 100 Ml:🥇Hot New Rasasi Premium Line🥇": "It'S Essential Edp Perfume By Rasasi 100 Ml:Hot New Rasasi Premium Line",
    "Boss Bottled Infinite By Hugo Boss Edp For Men 3.3 Oz / 100 Ml": "Boss Bottled Infinite By Hugo Boss",
    "Ocean Cologne Bath & Body Works 3.4 Oz 100 Ml Spray Men'S Collection Ne🦋": "Ocean Cologne Bath & Body Works 3.4 Oz 100 Ml Spray Men'S Collection Ne",
    "Sealed New Cupid Hypnosis Men’S Pheromone Cologne 1.7 Oz | Meet More Hot Women🔥": "Sealed New Cupid Hypnosis Men’S Pheromone Cologne 1.7 Oz Meet More Hot Women"
})
for col in ['title']:
    print(df[col].unique())
# Out:
# ["Christian Dior Sauvage Men'S Edp 3.4 Oz Fragrance Spray"
#  'A-V-Entus Eau De Parfum 3.3 Oz 100Ml Millesime Edp Col-Ogne For Men New In Box'
#  'Hogo Boss Cologne For Men 3.4 Oz'
#  "Acqua Di Gio By Giorgio Armani 6.7 Fl Oz Eau De Toilette Spray Men' New & Sealed"
#  "Lattafa Men'S Hayaati Al Maleky Edp Spray 3.4 Oz Fragrances 6291108734056"
#  "Men'S Perfume Sampler 10Pcs Sample Vials Designer Fragrance Samples For Men"
#  'Glacier Bold By Maison Alhambra 3.4Oz Edp For Men New Sealed Can'
#  'Parfums De-Marly-Haltane Eau De Parfum Spray 4.2 Oz For Men New In Box'
#  'Hawas For Him Eau De Parfum By Rasasi 100Ml 3.4 Fl Oz New'
#  'Gucci Guilty For Him - Classic 3Oz Eau De Toilette Spray, Brand New'
#  'Polo Blue By Ralph Lauren 4.2 Oz Edt Cologne For Men Brand New In Box'
#  'Dolce & Gabbana Light Blue Men 4.2 Oz / 125 Ml Edt Spray Brand New & Sealed'
#  'New 2024 Sexy Cologne Cupid Hypnosis Long Lasting Pheromone Perfume For Men'
# ...

# %% [markdown]
# **3. Type**

# %%
df['type'] = df['type'].str.title()
print(df['type'].unique())
# Out:
# ['Eau De Parfum' 'Eau De Toilette' 'Fragrances' 'Perfume' '/' 'Parfum'
#  'Concentrated Uncut Pure Body Oil' 'Le Parfum' nan 'Unscented'
#  'Eau De Cologne' '~ The One Eau De Parfum Spray ~' 'Extrait De Parfum'
#  'Eau De Parfum Intense' 'Pheromone' 'Aftershave' 'Fragrance & Perfume'
#  'Eau De Perfume' 'Jo Malone Cologne Intense Spray' 'Y' 'Gift Sets'
#  'Fragrance Rolling Ball' 'Body Spray' 'Eau De Toillette'
#  'Eau De Toilette, Eau De Parfum, Eau De Parfum Intense' 'Cologne'
#  'Eau De Toilette Intense' 'Eau De Cologne Spray, Cologne Spray'
#  'Fine Cologne' 'Does Not Apply' 'Edt' 'Editions Parfums'
#  'Dior Homme Cologne' 'Deodorant' 'De Nuit'
#  'Eau De Toilette, Cologne Spray' 'Parfum Intense' 'Eau De Cologne Spray'
#  'Roll On' 'Elixir De Parfum' 'Elixir' 'Various' 'Assorted'
#  'Fragrance Oil' 'Eau De Parfum/ Eau De Toilette' 'Deodorant Body Spray'
#  'Oil' 'Splash-On' 'Edc' 'Car Air Freshener' 'Fragrance Body Spray'
#  'Body Oil' 'Cologne Spray']

# %%
df['type'] = df['type'].replace({
    'edp': 'eau de parfum',
    'parfum': 'eau de parfum',
    'le parfum': 'eau de parfum',
    'eau de parfum spray': 'eau de parfum',
    'edt': 'eau de toilette',
    'eau de toillette': 'eau de toilette',
    'edc': 'eau de cologne',
    "~ The One Eau De Parfum Spray ~": "the one eau de parfum spray",
    "Eau De Parfum/ Eau De Toilette": "Eau De Parfum",
})

for col in ['type']:
    print(df[col].unique())
# Out:
# ['Eau De Parfum' 'Eau De Toilette' 'Fragrances' 'Perfume' '/' 'Parfum'
#  'Concentrated Uncut Pure Body Oil' 'Le Parfum' nan 'Unscented'
#  'Eau De Cologne' 'the one eau de parfum spray' 'Extrait De Parfum'
#  'Eau De Parfum Intense' 'Pheromone' 'Aftershave' 'Fragrance & Perfume'
#  'Eau De Perfume' 'Jo Malone Cologne Intense Spray' 'Y' 'Gift Sets'
#  'Fragrance Rolling Ball' 'Body Spray' 'Eau De Toillette'
#  'Eau De Toilette, Eau De Parfum, Eau De Parfum Intense' 'Cologne'
#  'Eau De Toilette Intense' 'Eau De Cologne Spray, Cologne Spray'
#  'Fine Cologne' 'Does Not Apply' 'Edt' 'Editions Parfums'
#  'Dior Homme Cologne' 'Deodorant' 'De Nuit'
#  'Eau De Toilette, Cologne Spray' 'Parfum Intense' 'Eau De Cologne Spray'
#  'Roll On' 'Elixir De Parfum' 'Elixir' 'Various' 'Assorted'
#  'Fragrance Oil' 'Deodorant Body Spray' 'Oil' 'Splash-On' 'Edc'
#  'Car Air Freshener' 'Fragrance Body Spray' 'Body Oil' 'Cologne Spray']

# %% [markdown]
# **4. Item Location**

# %%
df['itemLocation'] = df['itemLocation'].str.title()
print(df['itemLocation'].unique())
# Out:
# ['Allen Park, Michigan, United States' 'Atlanta, Georgia, Canada'
#  'Dearborn, Michigan, United States'
#  'Reinholds, Pennsylvania, United States'
#  'Brooklyn, New York, United States' 'Houston, Texas, United States'
#  'Englewood Cliffs, New Jersey, United States'
#  'Ithaca, New York, United States' 'Shanghai, China'
#  'Dearborn Heights, Michigan, United States'
#  'Ecorse, Michigan, United States' 'Warren, Michigan, United States'
#  'San Francisco, California, United States' 'Dayton,New Jersey, Hong Kong'
#  'San Jose, California, United States' 'Miami, Florida, United States'
#  'Hamtramck, Michigan, United States' 'Flat Lick, Kentucky, United States'
#  'Elmhurst, New York, United States'
#  'Hackensack, New Jersey, United States' 'Dallas, Texas, United States'
#  'Pomona, California, United States' 'Katy, Texas, United States'
#  'College Point, New York, United States' 'New York, United States'
#  'New York,Usa, Hong Kong' 'Brenham, Texas, United States'
# ...

# %%
df['itemLocation'] = df['itemLocation'].replace({
    'USA': 'United States',
    'Usa': 'United States',
    'United states': 'United States',
    'United States, United States': 'United States',
    'United States of America': 'United States',
    'California': 'United States',
    'HongKong': 'Hong Kong',
    'HK': 'Hong Kong',
    'HK, Hong Kong': 'Hong Kong',
    'Hong Kong, Hong Kong': 'Hong Kong',
    'Hong Kong, Hong Kong, Hong Kong': 'Hong Kong',
    'NEW YORK': 'New York',
    'New York, New York': 'New York',
})
print(df['itemLocation'].unique())
# Out:
# ['Allen Park, Michigan, United States' 'Atlanta, Georgia, Canada'
#  'Dearborn, Michigan, United States'
#  'Reinholds, Pennsylvania, United States'
#  'Brooklyn, New York, United States' 'Houston, Texas, United States'
#  'Englewood Cliffs, New Jersey, United States'
#  'Ithaca, New York, United States' 'Shanghai, China'
#  'Dearborn Heights, Michigan, United States'
#  'Ecorse, Michigan, United States' 'Warren, Michigan, United States'
#  'San Francisco, California, United States' 'Dayton,New Jersey, Hong Kong'
#  'San Jose, California, United States' 'Miami, Florida, United States'
#  'Hamtramck, Michigan, United States' 'Flat Lick, Kentucky, United States'
#  'Elmhurst, New York, United States'
#  'Hackensack, New Jersey, United States' 'Dallas, Texas, United States'
#  'Pomona, California, United States' 'Katy, Texas, United States'
#  'College Point, New York, United States' 'New York, United States'
#  'New York,Usa, Hong Kong' 'Brenham, Texas, United States'
# ...

# %% [markdown]
# **Kesimpulan Perubahan Pada Brand, titile, Type, dan Item Location**
#
# Pada kolom brand, title, Type, dan Item Location dilakukan proses perbaikan penulisan untuk mengatasi inkonsisten akibat perbedaan huruf kapital dan variasi penamaan. fungsi str.title() digunakan untuk menyeragamkan format penulisan sehingga setiap nama memiliki format penulisan kapital yang sama, kemudian dilakukan penggantian menggunakan replace() untuk mengganti beberapa nama yang sebenarnya sama, memperbaiki kesalahan penulisan dan mengganti kalimat yang memiliki simbol-simbol yang tidak dibutuhkan. Sehingga dapat mengurangi duplikasi kategori, membuat data lebih konsisten, dan dapat memudahkan dalam proses analisis selanjutnya.

# %% [markdown]
# **TAMBAHAN**

# %% [markdown]
# **1. Brand**

# %%
df = df[df['brand'] != 'As Show']
df = df[df['brand'] != 'As Picture Show']
df = df[df['brand'] != 'As Shown']
df = df[df['brand'] != 'Unbranded']
df = df[df['brand'] != 'Does Not Apply']
df = df[df['brand'] != 'Fragrance']
df = df[df['brand'] != 'Limited Edition']
df = df[df['brand'] != 'Multiple Brands']
print(df['brand'].unique())
# Out:
# ['Dior' 'Giorgio Armani' 'Lattafa' 'Maison Alhambra' 'Gucci'
#  'Ralph Lauren' 'Dolce&Gabbana' 'Secertmu' 'Versace' 'Paco Rabanne'
#  'Grandeur' 'Armaf' 'Carolina Herrera' 'Dolce & Gabbana' 'Clinique'
#  'Dumont' 'Afnan' 'Azzaro' "Penhaligon'S" 'Bharara' 'Valentino'
#  'Guy Laroche' 'Montblanc' 'Rasasi' 'Calvin Klein' 'Uomo' 'Givenchy'
#  'Polo Ralph Lauren' 'C.K' 'John Varvatos' 'Nautica' 'Kenneth Cole'
#  'Tommy Hilfiger' '2Nd To None' 'Yves Saint Laurent' 'Cologne' 'Roja'
#  'Metaherbal Labs' 'Mirage Brands' 'Abercrombie & Fitch' 'Moschino'
#  '~ Dolce & Gabbana ~' 'Superz Budapest' 'Gianni Versace' 'Christian Dior'
#  'Hermès' 'Diesel' 'Lacoste' 'Dossier' 'Burberry' 'Michael Malul' 'Zara'
#  'Aramis' 'Jean Paul Gaultier' 'Davidoff' 'As Picture Shown' 'Bvlgari'
#  'Parfums De Marly' 'Salvatore Ferragamo' 'Ard Al Zaafaran'
#  'Karl Lagerfeld' 'J. Del Pozo' 'Sean John' 'Ysl' 'Jaguar' 'Ebc'
#  'Bath & Body Works' 'Issey Miyake' 'King' 'Prada' 'Hugo Boss'
# ...

# %% [markdown]
# Pada tahap data preparation, ditemukan beberapa data yang tidak termasuk ke dalam kategori brand ataupun nama produk parfum. data tersebut merupakan label umum sehingga mengganggu dalam menggambarkan produk secara valid. oleh karena itu, dilakukan proses penghapusan terhadap data tersebut agar kualitas dataset menjadi lebih akurat serta mampu menggambarkan produk parfum secara lebih valid.

# %% [markdown]
# **2. type**

# %%
df = df[df['type'] != 'Fragrances']
df = df[df['type'] != 'Perfume']
df = df[df['type'] != 'Unscented']
df = df[df['type'] != 'Pheromone']
df = df[df['type'] != 'Aftershave']
df = df[df['type'] != 'Fragrance & Perfume']
df = df[df['type'] != 'Gift Sets']
df = df[df['type'] != 'Body Spray']
df = df[df['type'] != 'Deodorant']
df = df[df['type'] != 'Car Air Freshener']
df = df[df['type'] != 'Various']
df = df[df['type'] != 'Assorted']
df = df[df['type'] != 'Fragrance Oil']
df = df[df['type'] != 'Oil']
df = df[df['type'] != 'Roll On']
df = df[df['type'] != 'Body Oil']
df = df[df['type'] != 'Does not apply']
df = df[df['type'] != '/']
df = df[df['type'] != 'Y']

print(df['type'].unique())
# Out:
# ['Eau De Parfum' 'Eau De Toilette' 'Parfum'
#  'Concentrated Uncut Pure Body Oil' 'Le Parfum' nan 'Eau De Cologne'
#  'the one eau de parfum spray' 'Extrait De Parfum' 'Eau De Parfum Intense'
#  'Eau De Perfume' 'Jo Malone Cologne Intense Spray' 'Eau De Toillette'
#  'Eau De Toilette, Eau De Parfum, Eau De Parfum Intense' 'Cologne'
#  'Eau De Toilette Intense' 'Eau De Cologne Spray, Cologne Spray'
#  'Fine Cologne' 'Does Not Apply' 'Edt' 'Editions Parfums'
#  'Dior Homme Cologne' 'De Nuit' 'Eau De Toilette, Cologne Spray'
#  'Parfum Intense' 'Eau De Cologne Spray' 'Elixir De Parfum' 'Elixir'
#  'Deodorant Body Spray' 'Splash-On' 'Edc' 'Fragrance Body Spray'
#  'Cologne Spray']

# %% [markdown]
# Pada tahap data preparation, ditemukan sejumlah data yang tidak termasuk dalam kategori jenis parfum. Data tersebut berupa nama-nama yang berada di luar dari jenis parfum sehingga dapat mengganggu keakuratan dalam menggambarkan produk secara valid. Oleh karena itu, dilakukan proses pembersihan dengan menghapus data yang tidak relevan tersebut agar kualitas dataset menjadi lebih akurat, konsisten, dan mampu menggambarkan produk parfum secara lebih tepat.

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# **1. Brand**

# %%
df['brand'] = df['brand'].fillna(df['brand'].dropna().mode()[0])

# %% [markdown]
# **2. Type**

# %%
df['type'] = df['type'].fillna(df['type'].dropna().mode()[0])

# %% [markdown]
# **3. Available**

# %%
df['available'] = df['available'].fillna(df['available'].dropna().median())

# %% [markdown]
# **4. AvailableText**

# %%
df['availableText'] = df['availableText'].fillna(df['availableText'].dropna().mode()[0])

# %% [markdown]
# **5. Sold**

# %%
df['sold'] = df['sold'].fillna(df['sold'].dropna().median())

# %% [markdown]
# **6. Last Update**

# %%
df['lastUpdated'] = df['lastUpdated'].fillna(df['lastUpdated'].dropna().mode()[0])

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                    Null Ratio in %
# brand                          0.0
# title                          0.0
# type                           0.0
# price                          0.0
# priceWithCurrency              0.0
# available                      0.0
# availableText                  0.0
# sold                           0.0
# lastUpdated                    0.0
# itemLocation                   0.0

# %% [markdown]
# **Kesimpulan Perubahan Pada brand, type, avaible, avaibleText, Sold, dan lastt update**
#
# Pada tahap data preparation, dilakukan pengecekan missing values pada seluruh kolom dengan menghitung persentase nilai kosong. hasilnya menunjukkan bahwa kolom available memiliki missing values 11,1% dan sold 0,6%, sehingga dilakukan imputasi menggunakan median karena data numerik seperti stok dan jumlah penjualan memiliki distribusi yang biasanya tidak normal serta rentan terhadap outlier, sehingga median lebih stabil dalam merepresentasikan nilai tengah data. sementara itu, kolom brand 0,1%, type 0,3%, availableText 0,3%, dan lastUpdated 5,3% ditangani menggunakan modus karena merupakan data kategorikal dan waktu, sehingga nilai yang paling sering muncul digunakan untuk menggantikan data yang hilang. setelah proses imputasi dilakukan, seluruh kolom tidak lagi memiliki nilai kosong sehingga dataset menjadi lebih lengkap dan dapat digunakan pada tahap analisis selanjutnya.

# %% [markdown]
# ## **Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [brand, title, type, price, priceWithCurrency, available, availableText, sold, lastUpdated, itemLocation]
# Index: []

# %% [markdown]
# Pada tahap data preparation, dilakukan pengecekan duplicated values. Hasil dari pengecekan tidak ditemukan data yang terduplikasi pada dataset. hal ini menunjukkan bahwa setiap baris data sudah bersifat unik sehingga tidak terjadi pengulangan informasi, dan proses pembersihan data untuk duplikasi tidak perlu dilakukan.

# %% [markdown]
# ## **Outliers Values**

# %% [markdown]
# **1. Price**

# %%
columns_to_impute = ["price", "price"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# **2. Available**

# %%
columns_to_impute = ["available", "available"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# **3. Sold**

# %%
columns_to_impute = ["sold", "sold"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom      Persentase Outliers
# price                      0.0
# available                  0.0
# sold                       0.0

# %% [markdown]
# Pada tahap data preparation, dilakukan penanganan outlier pada kolom price, available, dan sold menggunakan metode IQR dengan menentukan batas bawah dan atas berdasarkan Q1 dan Q3. Nilai yang berada di luar rentang tersebut kemudian disesuaikan dengan nilai yang berada di luar batas wajar dengan menggantinya ke batas bawah atau batas atas yang telah ditentukan. Metode ini dipilih agar data tetap lengkap tanpa menghapus baris, sehingga pengaruh nilai ekstrem dapat diminimalkan dan data menjadi lebih mudah untuk dianalisis.

# %% [markdown]
# # **Construct Data**

# %% [markdown]
# **1. Sales Performance**

# %%
def kategori_penjualan(sold):
    if sold >= 100:
        return 'High'
    elif sold >= 30:
        return 'Medium'
    else:
        return 'Low'

df['sales_performance'] = df['sold'].apply(kategori_penjualan)

# %% [markdown]
# penambahan kolom sales_performance membantu mengelompokkan produk berdasarkan tingkat penjualannya sehingga lebih mudah melihat produk mana yang benar-benar diminati, cukup diminati, atau kurang laku tanpa harus membaca angka sold satu per satu

# %% [markdown]
# **2. Price Perunit Category**

# %%
def kategori_harga(price):
    if price >= 200:
        return 'Premium'
    elif price >= 100:
        return 'Mid Range'
    else:
        return 'Standard'

df['price_per_unit_category'] = df['price'].apply(kategori_harga)

# %% [markdown]
# kolom price_per_unit_category mempermudah analisis segmentasi harga dengan membagi produk ke dalam kategori budget, mid range, dan premium. Sehingga membantu mengidentifikasi apakah produk dengan harga tertentu memiliki performa penjualan yang lebih tinggi atau lebih rendah.

# %%
df
# Out:
#                brand                                              title  \
# 0               Dior  Christian Dior Sauvage Men'S Edp 3.4 Oz Fragra...
# 3     Giorgio Armani  Acqua Di Gio By Giorgio Armani 6.7 Fl Oz Eau D...
# 6    Maison Alhambra  Glacier Bold By Maison Alhambra 3.4Oz Edp For ...
# 9              Gucci  Gucci Guilty For Him - Classic 3Oz Eau De Toil...
# 10      Ralph Lauren  Polo Blue By Ralph Lauren 4.2 Oz Edt Cologne F...
# ..               ...                                                ...
# 995            Guess  Guess 1981 By Guess Cologne For Men Edt 3.3 / ...
# 996            Armaf  Club De Nuit Intense By Armaf Cologne For Men ...
# 997     Paco Rabanne  Invictus By Paco Rabanne For Men Edt Spray 3.4...
# 998           Lomani  Lomani Edt Cologne 3.4 Oz Men - Authentic, Bra...
# 999     Estee Lauder  Beyond Paradise By Estee Lauder For Men Cologn...
#
#                 type  price priceWithCurrency  available  \
# ...

# %% [markdown]
# Setelah itu dilakukan pengecekan ulang untuk memastikan apakah kolom Seles Performence dan Price Perunit Catagoy telah berhasil di tambahkan.

# %% [markdown]
# # **Data Reduction**

# %% [markdown]
# **1. Title**

# %%
df = df.drop('title', axis=1)

# %% [markdown]
# kolom title dihapus karena hanya berisi gabungan informasi dari beberapa kolom seperti brand, type, dan ukuran produk. Data tersebut adalah data duplikasi dari kolom lainnya, sehingga dianggap  tidak menambah nilai informasi pada dataset dan title dapat dihapus agar dataset dapat lebih ringkas dan efisien dalam proses analisis nantinya.

# %% [markdown]
# **2. Price With Currency**

# %%
df = df.drop('priceWithCurrency', axis=1)

# %% [markdown]
# Kolom priceWithCurrency dihapus karena hanya menampilkan harga dalam bentuk teks seperti “US $84.99/ea”. Sementara informasi harga yang dibutuhkan untuk analisis sudah tersedia pada kolom price. keberadaan kolom ini menjadi duplikat dan tidak menambah informasi baru, sehingga dihapus agar dataset lebih ringkas dan proses analisis lebih efisien.

# %% [markdown]
# **3. Available Text**

# %%
df = df.drop('availableText', axis=1)

# %% [markdown]
# kolom availableText dihapus karena informasi ketersediaan produk sudah ada pada kolom available dalam bentuk numerik yang lebih mudah dianalisis. karena fokus analisis berada pada data kuantitatif, kolom teks ini kurang relevan dan hanya membuat data menjadi lebih kompleks.

# %%
df
# Out:
#                brand             type  price  available    sold  \
# 0               Dior    Eau De Parfum  84.99       10.0  116.00
# 3     Giorgio Armani  Eau De Toilette  44.99        2.0  159.00
# 6    Maison Alhambra    Eau De Parfum  30.99        9.0   39.00
# 9              Gucci    Eau De Parfum  49.99        8.0   68.00
# 10      Ralph Lauren  Eau De Toilette  34.99       10.0  615.00
# ..               ...              ...    ...        ...     ...
# 995            Guess  Eau De Toilette  20.28       17.5  989.75
# 996            Armaf  Eau De Toilette  30.58       10.0   31.00
# 997     Paco Rabanne  Eau De Toilette  39.99        2.0  305.00
# 998           Lomani  Eau De Toilette   9.99        2.0   22.00
# 999     Estee Lauder    Cologne Spray  17.49       10.0   24.00
#
#             lastUpdated                                 itemLocation  \
# 0   2024-05-24 10:03:04          Allen Park, Michigan, United States
# ...

# %% [markdown]
# Setelah itu dilakukan pengecekan ulang untuk memastikan apakah kolom title, priceWithCurrency, dan availableText telah terhapus

# %% [markdown]
# # **Visualisasi Dataset**

# %% [markdown]
# ## **BAR CHART**

# %%
top_brand_count = df['brand'].value_counts().head(5).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(top_brand_count.index, top_brand_count.values, color='skyblue')
plt.xlabel('Brand')
plt.ylabel('Jumlah Produk')
plt.title('Top 5 Brand Parfum dengan Jumlah Produk Terbanyak')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**

# %% [markdown]
# Berdasarkan visualisasi bar chart di atas, dapat dilihat bahwa brand giorgio armani memiliki jumlah produk terbanyak dalam dataset, diikuti oleh paco rabanne dan ralph lauren, yang menunjukkan bahwa ketiga brand tersebut memiliki variasi produk yang cukup banyak dibandingkan brand lainnya. sementara itu armaf dan dolce & gabbana memiliki jumlah produk yang lebih rendah. kondisi ini menunjukkan bahwa distribusi produk parfum dalam dataset cenderung didominasi oleh beberapa brand tertentu yang memiliki lebih banyak variasi produk di pasar.

# %% [markdown]
# **Action**

# %% [markdown]
# Dari hasil analisis barchart, perusahaan disarankan untuk memfokuskan strategi pemasaran pada brand dengan jumlah produk tinggi seperti Giorgio Armani, Paco Rabanne, dan Ralph Lauren karena memiliki variasi produk lebih banyak dan berpotensi menjangkau lebih banyak konsumen. Sementara itu, brand dengan jumlah produk lebih sedikit seperti Armaf dan Dolce & Gabbana dapat dipertimbangkan untuk menambah variasi produk atau meningkatkan promosi agar mampu bersaing dengan brand lain yang memiliki lebih banyak pilihan.

# %% [markdown]
# ## **PIE CHART**

# %%
brand_sales = df.groupby('brand')['sold'].sum().sort_values(ascending=False)
top_brand_sales = brand_sales.head(3)

plt.figure(figsize=(9, 7))
top_brand_sales.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

plt.title('Kontribusi Penjualan Parfum Berdasarkan 3 Brand Teratas')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# **Insight**

# %% [markdown]
# Hasil visualisasi pie chart menunjukkan bahwa armaf memiliki kontribusi penjualan terbesar sebesar 35.7%, diikuti oleh giorgio armani sebesar 33.7%, dan ralph lauren sebesar 30.7%. meskipun perbedaannya tidak terlalu besar, armaf tetap menjadi brand dengan kontribusi penjualan tertinggi di antara tiga brand tersebut, yang menunjukkan bahwa produk dari brand ini memiliki tingkat penjualan yang paling tinggi dalam dataset. hal ini menunjukkan bahwa produk dari brand tersebut memiliki permintaan yang cukup tinggi dibandingkan brand lainnya

# %% [markdown]
# **Action**

# %% [markdown]
# Dari hasil analisis diatas, Perusahaan disarankan untuk lebih memfokuskan strategi pemasaran pada brand dengan jumlah produk yang tinggi seperti Giorgio Armani, Paco Rabanne, dan Ralph Lauren. selain itu, dapat dilakukan analisis lebih lanjut untuk mengetahui faktor yang mempengaruhi tingginya penjualan pada brand tersebut, seperti harga produk, variasi produk, atau strategi pemasaran yang digunakan, sehingga strategi serupa dapat diterapkan pada brand lain untuk meningkatkan penjualan.

# %% [markdown]
# ## **LINE CHART**

# %%
df['lastUpdated'] = pd.to_datetime(df['lastUpdated'])

monthly_update = df.groupby(df['lastUpdated'].dt.to_period('M')).size()

plt.figure(figsize=(20, 6))
plt.plot(monthly_update.index.astype(str), monthly_update.values, marker='o', color='blue')

plt.title('Jumlah Produk Parfum Berdasarkan Waktu Update per Bulan', fontsize=16) # Judul
plt.xlabel('Bulan Update', fontsize=12)
plt.ylabel('Jumlah Produk', fontsize=12)

plt.grid(True)
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**

# %% [markdown]
# Berdasarkan line chart diatas, terlihat bahwa aktivitas pembaruan produk hampir tidak terjadi dari akhir tahun 2022 hingga awal tahun 2024. Peningkatan baru mulai terlihat secara bertahap pada Februari hingga April 2024, yang kemudian diikuti lonjakan sangat signifikan pada Mei 2024 dengan jumlah produk yang diperbarui mencapai hampir 800. Pola ini menunjukkan bahwa kemungkinan terjadi penundaan pembaruan data dalam waktu cukup lama, lalu dilakukan input atau pembaruan produk secara massal dalam satu periode.

# %% [markdown]
# **Action**

# %% [markdown]
# Dari hasil analisis diatas, perlu dilakukan evaluasi terhadap proses pengelolaan dan pembaruan data produk agar pembaruan tidak tertunda terlalu lama dan tidak menumpuk dalam satu waktu. Perusahaan juga dapat menerapkan sistem pembaruan data yang lebih rutin dan terjadwal sehingga informasi produk tetap akurat dan mudah dipantau. Selain itu, karena terdapat lonjakan produk baru pada Mei 2024, tim pemasaran dapat memanfaatkan momentum tersebut dengan meningkatkan promosi atau strategi pemasaran agar produk-produk yang baru diperbarui dapat lebih cepat dikenal dan diminati oleh konsumen.

# %% [markdown]
# ## **HISTOGRAM**

# %%
plt.figure(figsize=(8,5))
plt.hist(df['price'], bins=20, color='skyblue', edgecolor='black')
plt.title('distribusi harga parfum')
plt.xlabel('harga')
plt.ylabel('frekuensi')
plt.show()

# %% [markdown]
# **Insight**

# %% [markdown]
# Berdasarkan histogram distribusi harga parfum,terlihat bahwa Distribusi harga pada grafik tersebut cenderung skewed right. selain itu sebagian besar produk berada pada rentang harga sekitar 20 - 40, yang menunjukkan bahwa mayoritas parfum dalam dataset berada pada kategori harga menengah. Meskipun jumlah produk cenderung menurun seiring bertambahnya harga, terdapat juga lonjakan frekuensi yang signifikan pada kategori harga tinggi di atas 100. Hal ini menunjukkan bahwa pasar didominasi oleh produk ekonomis, namun tetap memiliki segmen pasar khusus untuk produk premium atau mewah.

# %% [markdown]
# **Action**

# %% [markdown]
# Melihat distribusi tersebut, perusahaan dapat lebih fokus pada strategi pemasaran untuk produk pada rentang harga menengah karena segmen ini memiliki jumlah produk paling banyak dan kemungkinan memiliki permintaan pasar yang besar. Selain itu, produk dengan harga tinggi dapat diposisikan sebagai produk premium dengan strategi promosi yang lebih eksklusif untuk menarik konsumen tertentu. Analisis harga ini juga dapat membantu perusahaan dalam menentukan strategi penetapan harga yang lebih seimbang agar dapat menjangkau berbagai segmen konsumen di pasar.

# %% [markdown]
# ## **BOX PLOT**

# %%
top_brand = df['brand'].value_counts().head(5).index
df_top_brand = df[df['brand'].isin(top_brand)]

plt.figure(figsize=(12, 7))
sns.boxplot(x='brand',y='price',data=df_top_brand,palette='viridis',order=top_brand,hue='brand',legend=False)
plt.title('Distribusi Harga Parfum pada 5 Brand Teratas', fontsize=16) # Judul
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Harga', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**

# %% [markdown]
# Berdasarkan box plot distribusi diatas, terlihat bahwa setiap brand memiliki variasi harga yang berbeda beda. Brand Paco Rabanne dan Dolce & Gabbana memiliki rentang harga yang luas, yang menunjukkan bahwa brand tersebut menawarkan produk dari harga menengah hingga tinggi. Sementara itu, Ralph Lauren dan Armaf cenderung memiliki harga yang stabil dengan rentang yang tidak terlalu luas, menandakan produk mereka lebih konsisten pada segmen harga tertentu. Selain itu, terlihat juga beberapa outlier pada brand alph Lauren dan Armaf yang menunjukkan adanya produk dengan harga jauh lebih tinggi dibandingkan harga rata-rata.

# %% [markdown]
# **Action**

# %% [markdown]
# Berdasarkan hasil analisis tersebut, perusahaan dapat menyesuaikan strategi pemasaran sesuai dengan harga setiap brand. Brand dengan rentang harga yang luas dapat diposisikan untuk menjangkau berbagai segmen konsumen, mulai dari menengah hingga premium. Sementara itu, brand dengan harga yang tidak terlalu luas dapat difokuskan pada segmen pasar tertentu agar posisi produknya lebih jelas. Selain itu, produk dengan harga tinggi yang muncul sebagai outlier dapat dipromosikan sebagai produk premium untuk meningkatkan kesan eksklusif serta menarik konsumen yang mencari parfum dengan kualitas yang tinggi.

# %% [markdown]
# ## **SCATTER PLOT**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='sold', hue='sales_performance', data=df)

plt.title('Hubungan Harga dan Jumlah Produk Terjual Berdasarkan Sales Performance') # Judul
plt.xlabel('Harga Produk')
plt.ylabel('Jumlah Terjual')
plt.legend(title='Sales Performance')

plt.show()

# %% [markdown]
# **Insight**

# %% [markdown]
# Berdasarkan scatter plot diatas, terlihat bahwa produk dengan performa penjualan High memiliki jumlah penjualan yang jauh lebih besar dibandingkan kategori lainnya dan tersebar pada berbagai rentang harga. Hal ini menunjukkan bahwa tingginya penjualan tidak selalu bergantung pada harga yang rendah, karena beberapa produk dengan harga menengah hingga tinggi dapat memiliki penjualan yang tinggi. Sementara itu, kategori Medium memiliki jumlah penjualan yang lebih stabil pada kisaran tertentu, dan kategori Low cenderung memiliki jumlah penjualan yang rendah di hampir seluruh rentang harga.

# %% [markdown]
# **Action**

# %% [markdown]
# Berdasarkan analisis scatter plot tersebut, perusahaan dapat melakukan analisis lebih lanjut terhadap produk dengan kategori High sales performance untuk mengetahui faktor yang membuat produk tersebut laris, seperti kualitas produk, popularitas brand, atau strategi pemasaran yang digunakan. Strategi tersebut kemudian dapat diterapkan pada produk lain untuk meningkatkan penjualan. Selain itu, produk dengan kategori Low dapat dievaluasi kembali dari harga, startegi promosi, atau penepatan produk di pasar agar lebih menarik bagi konsumen dan berpotensi meningkatkan performa penjualannya.

# %% [markdown]
# ## **BUBBLE CHART**

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='price',y='sold',size='available',hue='sales_performance',data=df,sizes=(50, 1000),alpha=0.7,palette='viridis')
plt.title('Hubungan Harga dan Penjualan Parfum (Ukuran: Stok Tersedia, Warna: Sales Performance)', fontsize=16)
plt.xlabel('Harga Parfum', fontsize=12)
plt.ylabel('Jumlah Terjual', fontsize=12)
plt.grid(True)
plt.legend(title='Sales Performance', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**

# %% [markdown]
# Berdasarkan visualisasi buble chart di atas, dapat dilihat bahwa harga tidak selalu menentukan tinggi rendahnya penjualan. Beberapa parfum dengan harga menengah hingga tinggi tetap mampu mencapai jumlah penjualan yang besar, sementara ada juga parfum dengan harga lebih murah tetapi penjualannya tetap rendah. Hal ini menunjukkan bahwa faktor lain seperti kualitas produk, merek, atau preferensi konsumen kemungkinan lebih mempengaruhi keputusan pembelian. Selain itu, dapat dilihat beberapa produk memiliki stok yang cukup besar namun penjualannya rendah, yang menandakan adanya produk yang kurang diminati di pasar.

# %% [markdown]
# **Action**

# %% [markdown]
# Berdasarkan hasil analisi tersebut, perusahan dapat mengambil langkah untuk mengevaluasi produk dengan penjualan rendah, meskipun memiliki stok tinggi agar tidak terjadi penumpukan barang. Selain itu, produk dengan performa penjualan tinggi dapat diprioritaskan dalam promosi dan pengelolaan stok agar mampu memenuhi permintaan pasar. Penyesuaian strategi pemasaran dan pengelolaan stok juga perlu dilakukan agar jumlah persediaan dapat memenuhi permintaan konsumen.

# %% [markdown]
# ## **HEATMAP**

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[['price','available','sold']].corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap Korelasi Variabel Numerik')
plt.show()

# %% [markdown]
# **Insight**

# %% [markdown]
# Berdasarkan visualisasi heatmap diatas, terlihat bahwa hubungan antara price dan sold memiliki korelasi -0,16  yang sangat lemah . Hal ini menunjukkan bahwa kenaikan atau penurunan harga tidak terlalu berpengaruh terhadap jumlah produk yang terjual. Sementara itu, stok available memiliki korelasi 0,44 yang berarti memiliki hubungan sedang dengan jumlah terjual , yang berarti semakin banyak stok yang tersedia, cenderung semakin banyak pula produk yang dapat terjual. Ini menunjukkan bahwa ketersediaan produk memiliki pengaruh terhadap penjualan dibandingkan faktor harga.

# %% [markdown]
# **Action**

# %% [markdown]
# Berdasarkan hasil analisis tersebut, strategi yang dapat dilakukan adalah memastikan ketersediaan stok produk tetap terjaga, terutama untuk produk yang memiliki potensi penjualan tinggi agar tidak terjadi kehabisan stok saat permintaan nantinya meningkat. Selain itu, penentuan harga tidak perlu terlalu tinggi ataupun rendah karena perubahan harga tidak terlalu berdampak besar terhadap jumlah penjualan. Fokus utama juga dapat diarahkan pada pengelolaan stok dan strategi pemasaran agar produk lebih mudah dijangkau dan tersedia bagi konsumen.

# %% [markdown]
# # **Menyimpan Dataset**

# %%
Datafile.to_csv('/content/drive/MyDrive/Praktikum/ebay_mens_perfume (1).csv', index=False)
